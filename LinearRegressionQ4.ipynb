# %% [markdown]
# <a href="https://colab.research.google.com/github/sreshtav-0/Machine-Learning/blob/LinearRegression/LinearRegressionQ4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
sm=pd.read_csv("/content/Super market - Sheet1.csv")
sm
# Out:
#      sales product_category      price   discount  day_of_week  \
# 0     7370                B  93.685010  28.602430            5
# 1      960                A   6.145157  25.633390            3
# 2     5490                D  54.588340  14.674440            2
# 3     5291                C  71.196990  46.587690            5
# 4     5834                B  87.225940  19.850750            3
# ..     ...              ...        ...        ...          ...
# 995   7247                A  22.687810  32.415900            1
# 996   4551                C   4.635415   3.705271            3
# 997   3976                C  11.694550  18.773450            6
# 998   6059                B  34.547200  40.190730            2
# 999    226                A  80.455980  21.673610            6
#
#      special_promotion
# 0                    1
# 1                    1
# 2                    0
# 3                    0
# 4                    0
# ..                 ...
# 995                  0
# ...

# %%
y=sm['sales']
y
# Out:
# 0      7370
# 1       960
# 2      5490
# 3      5291
# 4      5834
#        ...
# 995    7247
# 996    4551
# 997    3976
# 998    6059
# 999     226
# Name: sales, Length: 1000, dtype: int64

# %%
x=sm.drop("sales", axis=1)
x
# Out:
#          price   discount  day_of_week  special_promotion
# 0    93.685010  28.602430            5                  1
# 1     6.145157  25.633390            3                  1
# 2    54.588340  14.674440            2                  0
# 3    71.196990  46.587690            5                  0
# 4    87.225940  19.850750            3                  0
# ..         ...        ...          ...                ...
# 995  22.687810  32.415900            1                  0
# 996   4.635415   3.705271            3                  1
# 997  11.694550  18.773450            6                  1
# 998  34.547200  40.190730            2                  0
# 999  80.455980  21.673610            6                  1
#
# [1000 rows x 4 columns]

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x, y, train_size=0.8, random_state=0)

# %%
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((800, 4), (200, 4), (800,), (200,))

# %%
LR=LinearRegression()
LR.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred=LR.predict(pd.DataFrame(xtest))

# %%
c = [i for i in range(1, 201)]
fig = plt.figure()
plt.plot(c, ytest, color = "Blue", linewidth = 2, linestyle = "--", label = "Actual")
plt.plot(c, ypred, color = "Black", linewidth = 3, linestyle = "-", label = "Predicted")
plt.legend()
plt.title("Price based on SuperMarket accomondations")
plt.xlabel("FACTORS")
plt.ylabel("Price")
plt.show()
