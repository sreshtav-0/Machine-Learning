# %% [markdown]
# <a href="https://colab.research.google.com/github/sreshtav-0/Machine-Learning/blob/LogisticRegression/LogisticRegressionQ3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
loan = pd.read_csv("/content/loan_data.csv. - Sheet1.csv")
loan
# Out:
#      Age  Income  Loanamount  Creditscore Default
# 0     41   67133       20262          543      NO
# 1     43   76017       18434          537     YES
# 2     51   81433       15195          511      NO
# 3     39   72243       13302          460     YES
# 4     55   84449       19914          452      NO
# ..   ...     ...         ...          ...     ...
# 115   55   59345       21254          591     YES
# 116   39   63302       26012          417     YES
# 117   58   62971       22397          477     YES
# 118   45   80861       15206          595      NO
# 119   63   78113       28834          568      NO
#
# [120 rows x 5 columns]

# %%
x=loan.iloc[:, :3]
y=loan.iloc[:, 4]

# %%
scaler=StandardScaler()

# %%
x
# Out:
#      Age  Income  Loanamount
# 0     41   67133       20262
# 1     43   76017       18434
# 2     51   81433       15195
# 3     39   72243       13302
# 4     55   84449       19914
# ..   ...     ...         ...
# 115   55   59345       21254
# 116   39   63302       26012
# 117   58   62971       22397
# 118   45   80861       15206
# 119   63   78113       28834
#
# [120 rows x 3 columns]

# %%
y
# Out:
# 0       NO
# 1      YES
# 2       NO
# 3      YES
# 4       NO
#       ...
# 115    YES
# 116    YES
# 117    YES
# 118     NO
# 119     NO
# Name: Default, Length: 120, dtype: object

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x, y, train_size=0.8, random_state=0)

# %%
xtrain=scaler.fit_transform(xtrain)

# %%
xtest=scaler.transform(xtest)

# %%
model=LogisticRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
ypred=model.predict(xtest)

# %%
accuracy_score(ypred, ytest)
# Out:
# 0.6666666666666666

# %%
confusion_matrix(ypred, ytest)
# Out:
# array([[16,  7],
#        [ 1,  0]])
